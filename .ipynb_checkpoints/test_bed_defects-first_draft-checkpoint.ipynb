# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
#% matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17771704634069923878
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5448120416
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 7125609162893244938
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1"
# ]

# %%
#Augmentation
image_gen = keras.preprocessing.image.ImageDataGenerator(rotation_range=20,  # rotate the image 20 degrees
                                                         width_shift_range=0.2,
                                                         height_shift_range=0.2,
                                                         rescale=1 / 255,  # Rescale the image by normalzing it.
                                                         shear_range=0.15,
                                                         # Shear means cutting away part of the image (max 20%)
                                                         zoom_range=0.15,  # Zoom in by 15% max
                                                         horizontal_flip=True,  # Allo horizontal flipping
                                                         fill_mode='nearest'
                                                         # Fill in missing pixels with the nearest filled value
                                                         )

# %%
# width,height,channels
image_shape = (180, 180, 3)

# %%
#train_data_path = './drive/MyDrive/Bachelor/data_balanced/train' #google colab
#test_data_path = './drive/MyDrive/Bachelor/data_balanced/test' #google colab
#validation_data_path = './drive/MyDrive/Bachelor/data_balanced/validation' #google colab
train_data_path = './data/test-bed-deffects/data_balanced/train'  #local notebook
test_data_path = './data/test-bed-deffects/data_balanced/test'  #local notebook
validation_data_path = './data/test-bed-deffects/data_balanced/validation'  #local notebook

# %%
batch_size = 16

train_image_gen = image_gen.flow_from_directory(train_data_path,
                                                target_size=(180, 180),
                                                batch_size=batch_size,
                                                class_mode='binary')
#train_image_gen = image_gen.flow_from_directory('./drive/MyDrive/Bachelor/data_balanced/train')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
train_image_gen.image_shape
# Out:
# (180, 180, 3)

# %%
test_image_gen = image_gen.flow_from_directory(test_data_path,
                                               target_size=(180, 180),
                                               batch_size=batch_size,
                                               class_mode='binary')
#test_image_gen = image_gen.flow_from_directory('./drive/MyDrive/Bachelor/data_balanced/test')
# Out:
# Found 998 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'DEF': 0, 'OK': 1}

# %%
valid_set = image_gen.flow_from_directory(validation_data_path,
                                          target_size=(180, 180),
                                          batch_size=batch_size,
                                          class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %%
valid_set.class_indices
# Out:
# {'DEF': 0, 'OK': 1}

# %%
base_model = keras.applications.vgg16.VGG16(
    include_top=False, weights='imagenet')

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
#TODO!!
#input = keras.applications.vgg16.preprocess_input(train_image_gen)

# %%
#Create your own input format (here 3x200x200)
#input = keras.applications.vgg16.preprocess_input(train_image_gen)
input = keras.Input(shape=(180, 180, 3), name='image_input')

#Use the generated model 
#output_vgg16_conv = model_vgg16_conv(input)

#Use the generated model 
output_vgg16_conv = base_model(input)

#Add the fully-connected layers 
x = keras.layers.Flatten(name='flatten')(output_vgg16_conv)
x = keras.layers.Dense(1000)(x)
x = keras.layers.Dropout(0.25)(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dense(1)(x)
x = keras.layers.Activation('sigmoid')(x)

#Create your own model
my_model = keras.models.Model(input, x)

#In the summary, weights and layers from VGG part will be hidden, but they will be fit during the training
my_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# image_input (InputLayer)     [(None, 180, 180, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, None, None, 512)   14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 12800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              12801000
# _________________________________________________________________
# dropout (Dropout)            (None, 1000)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1000)              4000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1001
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 27,520,689
# Trainable params: 27,518,689
# Non-trainable params: 2,000
# _________________________________________________________________

# %%
custom_early_stopping = keras.callbacks.EarlyStopping(patience=20)

# %%
for layer in base_model.layers:
    layer.trainable = False
optimizer = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)
my_model.compile(loss="binary_crossentropy", optimizer=optimizer,
                 metrics=["accuracy"])
history = my_model.fit(train_image_gen,
                       validation_data=test_image_gen,
                       epochs=5)
# Out:
# Epoch 1/5
# 125/125 [==============================] - 17s 125ms/step - loss: 0.9256 - accuracy: 0.5813 - val_loss: 0.5132 - val_accuracy: 0.7585
# Epoch 2/5
# 125/125 [==============================] - 15s 121ms/step - loss: 0.6494 - accuracy: 0.6770 - val_loss: 0.6034 - val_accuracy: 0.7395
# Epoch 3/5
# 125/125 [==============================] - 15s 121ms/step - loss: 0.6224 - accuracy: 0.7042 - val_loss: 0.7160 - val_accuracy: 0.7315
# Epoch 4/5
# 125/125 [==============================] - 15s 122ms/step - loss: 0.6121 - accuracy: 0.7139 - val_loss: 0.4765 - val_accuracy: 0.7976
# Epoch 5/5
# 125/125 [==============================] - 15s 122ms/step - loss: 0.6033 - accuracy: 0.7074 - val_loss: 0.4550 - val_accuracy: 0.8076

# %%
for layer in base_model.layers:
    layer.trainable = True

optimizer = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)
my_model.compile(loss="binary_crossentropy", optimizer=optimizer,
                 metrics=["accuracy"])
history = my_model.fit(train_image_gen,
                       validation_data=test_image_gen,
                       epochs=100,
                       callbacks=[custom_early_stopping])
# Out:
# Epoch 1/100
# 125/125 [==============================] - 23s 167ms/step - loss: 0.8217 - accuracy: 0.6276 - val_loss: 0.3161 - val_accuracy: 0.8747
# Epoch 2/100
# 125/125 [==============================] - 21s 165ms/step - loss: 0.4915 - accuracy: 0.7966 - val_loss: 0.4322 - val_accuracy: 0.8497
# Epoch 3/100
# 125/125 [==============================] - 21s 165ms/step - loss: 0.4042 - accuracy: 0.8432 - val_loss: 0.2990 - val_accuracy: 0.8798
# Epoch 4/100
# 125/125 [==============================] - 21s 165ms/step - loss: 0.3311 - accuracy: 0.8808 - val_loss: 0.2890 - val_accuracy: 0.8908
# Epoch 5/100
# 125/125 [==============================] - 21s 165ms/step - loss: 0.2951 - accuracy: 0.8960 - val_loss: 0.2426 - val_accuracy: 0.9088
# Epoch 6/100
# 125/125 [==============================] - 21s 166ms/step - loss: 0.2942 - accuracy: 0.8935 - val_loss: 0.2578 - val_accuracy: 0.9018
# Epoch 7/100
# 125/125 [==============================] - 21s 165ms/step - loss: 0.2917 - accuracy: 0.8906 - val_loss: 0.2684 - val_accuracy: 0.9048
# Epoch 8/100
# 125/125 [==============================] - 21s 166ms/step - loss: 0.2849 - accuracy: 0.9020 - val_loss: 0.3168 - val_accuracy: 0.9028
# Epoch 9/100
# 125/125 [==============================] - 21s 166ms/step - loss: 0.3111 - accuracy: 0.8787 - val_loss: 0.2453 - val_accuracy: 0.9168
# 125/125 [==============================] - 21s 166ms/step - loss: 0.2482 - accuracy: 0.9201 - val_loss: 0.2307 - val_accuracy: 0.9309
# Epoch 29/100
# 125/125 [==============================] - 21s 166ms/step - loss: 0.2365 - accuracy: 0.9311 - val_loss: 0.2605 - val_accuracy: 0.9088
# Epoch 30/100
# 125/125 [==============================] - 21s 167ms/step - loss: 0.2574 - accuracy: 0.9178 - val_loss: 0.2547 - val_accuracy: 0.9078
# Epoch 31/100
# 125/125 [==============================] - 21s 166ms/step - loss: 0.2552 - accuracy: 0.9167 - val_loss: 0.2298 - val_accuracy: 0.9228

# %%
# serialize to JSON
my_model_v1 = my_model.to_json()
with open('./saved_model/my_model_v1.json', "w") as file:
    file.write(my_model_v1)
# serialize weights to HDF5
my_model.save_weights('./saved_model/my_model_v1_weights.h5')

# %%
def load_model(model_path, weight_path):
    # load json and create model
    file = open(model_path, 'r')
    model_json = file.read()
    file.close()
    loaded_model = keras.models.model_from_json(model_json)
    # load weights
    loaded_model.load_weights(weight_path)
    optimizer = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)
    loaded_model.compile(loss="binary_crossentropy", optimizer=optimizer,
                         metrics=['accuracy', 'Recall', 'Precision', 'AUC'])
    return loaded_model

# %%
model = load_model('./saved_model/my_model_v1.json', './saved_model/my_model_v1_weights.h5')

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)  # set the vertical range to [0-1]
plt.show()

# %%
import cv2

def load_img(path_to_img):
    loaded_img = cv2.imread(path_to_img)
    loaded_img = cv2.cvtColor(loaded_img, cv2.COLOR_BGR2RGB)
    loaded_img = cv2.resize(loaded_img, (180, 180)) / 255
    return loaded_img.reshape(1, 180, 180, 3)

# %%
img_original = cv2.imread('./data/test-bed-deffects/data_balanced/validation/DEF/validation_DEF_4.jpeg')
#img = cv2.cvtColor(img_original, cv2.COLOR_BGR2RGB)
img_rgb = cv2.cvtColor(img_original, cv2.COLOR_BGR2RGB)
img = cv2.resize(img_rgb,(180,180)) / 255
plt.imshow(img)
img = img.reshape(1,180,180,3) # return the image with shaping that TF wants.
img.shape
# Out:
# (1, 180, 180, 3)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999)
model.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=['accuracy', 'Recall', 'Precision', 'AUC'])
prediction = model.predict(load_img('./data/test-bed-deffects/data_balanced/validation/DEF/validation_DEF_4.jpeg'))
print(f'Probability that image shows a test bed which is OK is: {prediction} ')
# Out:
# Probability that image shows a test bed which is OK is: [[0.53802127]]

# %%
valid_set.image_shape
# Out:
# (180, 180, 3)

# %%
# metrics from the paper:
# accuracy = 0.959, precision = 0.939, recall = 0.980, f1-score = 0.959, auc value = 0.982
loss, accuracy, recall, precision, auc = model.evaluate(valid_set)
# Out:
# 63/63 [==============================] - 7s 93ms/step - loss: 0.2316 - accuracy: 0.9279 - recall: 0.9765 - precision: 0.8921 - auc: 0.9460

# %%
f1 = 2 * ((precision * recall) / (precision + recall))
f1
# Out:
# 0.9194756563035986
